# %% [markdown]
# # pydicom

# %%
import pydicom
print(pydicom.__version__)
# Out:
# 2.1.2

# %%
ds_sample = pydicom.read_file('../sample/dcmseg.dcm')

# %%
ds_sample
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 220
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Segmentation Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.835820480179220400440467476247369788298
# (0002, 0010) Transfer Syntax UID                 UI: RLE Lossless
# (0002, 0012) Implementation Class UID            UI: 2.25.80302813137786398554742050926734630921603366648225212145404
# (0002, 0013) Implementation Version Name         SH: 'dcmjs-0.0'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Segmentation Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.835820480179220400440467476247369788298
# (0008, 0020) Study Date                          DA: '20140802'
# ...

# %%
ds_sample.Modality
# Out:
# 'SEG'

# %%
ds_sample['Modality']
# Out:
# (0008, 0060) Modality                            CS: 'SEG'

# %%
ds_sample['Modality'].value
# Out:
# 'SEG'

# %%
ds_sample.PerFrameFunctionalGroupsSequence[0].FrameContentSequence[0].DimensionIndexValues
# Out:
# [1, 1]
